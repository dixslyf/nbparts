# %% [markdown]
# This is an attachment:
#
# ![sine.png](attachment:859415a7-1577-4262-90ed-64746a4b78b0.png)

# %% [markdown]
# This is a cell with multiple attachments.
#
# ![sine.gif](attachment:77f7ac13-b7e8-44b9-b082-fba5ed60f426.gif)
#
# ![sine.png](attachment:99802af4-a3b8-4516-aba4-06a902ec8bdd.png)
